# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dataset/ecommerce_dataset_updated.csv', encoding='unicode_escape')

# %%
data.head()
# Out:
#     User_ID  Product_ID  Category  Price (Rs.)  Discount (%)  \
# 0  337c166f  f414122f-e    Sports        36.53            15
# 1  d38a19bf  fde50f9c-5  Clothing       232.79            20
# 2  d7f5f0b0  0d96fc90-3    Sports       317.02            25
# 3  395d4994  964fc44b-d      Toys       173.19            25
# 4  a83c145c  d70e2fc6-e    Beauty       244.80            20
#
#    Final_Price(Rs.) Payment_Method Purchase_Date
# 0             31.05    Net Banking    12-11-2024
# 1            186.23    Net Banking    09-02-2024
# 2            237.76    Credit Card    01-09-2024
# 3            129.89            UPI    01-04-2024
# 4            195.84    Net Banking    27-09-2024

# %%
price = data['Price (Rs.)']

price_range = price.max() - price.min()

price_variance = price.var()

price_std = price.std()

# %%
print(f"Price Range : {price_range}\nPrice Variance : {price_variance}\nPrice Standard Deviation : {price_std}")
# Out:
# Price Range : 489.87
# Price Variance : 20073.965183939068
# Price Standard Deviation : 141.68262131940907

# %%
plt.hist(price, bins=30, edgecolor='black')
plt.title('Product Price Distribution')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x=price)
plt.title('Product Price Boxplot')
plt.xlabel('Price')
plt.show()
